# %%
# congratulations! you have discovered this empty notebook! 
# i set it up a long long time ago with the intention of putting the topic cleaning in here, but in fact did that in '3. topics and subject areas.ipynb'

# have a nice day!
