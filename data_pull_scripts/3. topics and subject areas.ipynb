# %% [markdown]
# # Data Cleaning and Aggregation - Topics and Subject Areas

# %% [markdown]
# ### Import Packages and Prerequisites

# %%
import pandas as pd
import numpy as np
import json
import ast

from datetime import datetime

pd.set_option('display.float_format', lambda x: '%.1f' % x)
pd.set_option('display.max_columns', None)

#sfu_works = pd.read_csv('../data_pulls/sfu_all_works.csv')
sfu_works = pd.read_csv('../data_pulls/sfu_all_works.csv')

# %%
works_json = sfu_works.to_json()
#print("done")
# Out:
# done

# %%
#print(sfu_works.shape)
#print(sfu_works.columns)
#sfu_works.head()
# Out:
# (76593, 51)
# Index(['id', 'doi', 'title', 'display_name', 'publication_year',
#        'publication_date', 'ids', 'language', 'primary_location', 'type',
#        'type_crossref', 'indexed_in', 'open_access', 'authorships',
#        'institution_assertions', 'countries_distinct_count',
#        'institutions_distinct_count', 'corresponding_author_ids',
#        'corresponding_institution_ids', 'apc_list', 'apc_paid', 'fwci',
#        'has_fulltext', 'cited_by_count', 'citation_normalized_percentile',
#        'cited_by_percentile_year', 'biblio', 'is_retracted', 'is_paratext',
#        'primary_topic', 'topics', 'keywords', 'concepts', 'mesh',
#        'locations_count', 'locations', 'best_oa_location',
#        'sustainable_development_goals', 'grants', 'datasets', 'versions',
#        'referenced_works_count', 'referenced_works', 'related_works',
#        'abstract_inverted_index', 'cited_by_api_url', 'counts_by_year',
#        'updated_date', 'created_date', 'is_authors_truncated',
#        'fulltext_origin'],
#       dtype='object')
#                                  id  \
# 0  https://openalex.org/W2140190241
# 1  https://openalex.org/W4288079944
# 2  https://openalex.org/W2107140090
# 3  https://openalex.org/W2064853889
# 4  https://openalex.org/W2141718064
#
#                                            doi  \
# 0       https://doi.org/10.5860/choice.49-3305
# 1  https://doi.org/10.1051/0004-6361/201833910
# 2    https://doi.org/10.1017/s1464793105006950
# 3        https://doi.org/10.1145/335191.335372
# 4        https://doi.org/10.1093/aesa/87.6.651
#
#                                                title  \
# 0               Data mining: concepts and techniques
# 1                          <i>Planck</i>2018 results
# 2  Freshwater biodiversity: importance, threats, ...
# 3  Mining frequent patterns without candidate gen...
# 4  Evolution, Weighting, and Phylogenetic Utility...
#
#                                         display_name  publication_year  \
# 0               Data mining: concepts and techniques              2012
# 1                          <i>Planck</i>2018 results              2020
# 2  Freshwater biodiversity: importance, threats, ...              2005
# 3  Mining frequent patterns without candidate gen...              2000
# 4  Evolution, Weighting, and Phylogenetic Utility...              1994
#
#   publication_date                                                ids  \
# 0       2012-02-01  {'openalex': 'https://openalex.org/W2140190241...
# 1       2020-04-03  {'openalex': 'https://openalex.org/W4288079944...
# 2       2005-12-12  {'openalex': 'https://openalex.org/W2107140090...
# 3       2000-05-16  {'openalex': 'https://openalex.org/W2064853889...
# 4       1994-11-01  {'openalex': 'https://openalex.org/W2141718064...
#
#   language                                   primary_location     type  \
# 0       en  {'is_oa': False, 'landing_page_url': 'https://...  article
# 1       en  {'is_oa': True, 'landing_page_url': 'https://d...  article
# 2       en  {'is_oa': False, 'landing_page_url': 'https://...   review
# 3       en  {'is_oa': False, 'landing_page_url': 'https://...  article
# 4       en  {'is_oa': False, 'landing_page_url': 'https://...  article
#
#      type_crossref                         indexed_in  \
# 0  journal-article                       ['crossref']
# 1  journal-article  ['arxiv', 'crossref', 'datacite']
# 2  journal-article             ['crossref', 'pubmed']
# 3  journal-article                       ['crossref']
# 4  journal-article                       ['crossref']
#
#                                          open_access  \
# 0  {'is_oa': True, 'oa_status': 'green', 'oa_url'...
# 1  {'is_oa': True, 'oa_status': 'bronze', 'oa_url...
# 2  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...
# 3  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...
# 4  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...
#
#                                          authorships institution_assertions  \
# 0  [{'author_position': 'first', 'author': {'id':...                     []
# 1  [{'author_position': 'first', 'author': {'id':...                     []
# 2  [{'author_position': 'first', 'author': {'id':...                     []
# 3  [{'author_position': 'first', 'author': {'id':...                     []
# 4  [{'author_position': 'first', 'author': {'id':...                     []
#
#    countries_distinct_count  institutions_distinct_count  \
# 0                         2                            2
# 1                        21                          105
# 2                         9                            9
# 3                         1                            1
# 4                         2                            2
#
#   corresponding_author_ids corresponding_institution_ids  \
# 0                       []                            []
# 1                       []                            []
# 2                       []                            []
# 3                       []                            []
# 4                       []                            []
#
#                                             apc_list apc_paid   fwci  \
# 0                                                NaN      NaN 1728.3
# 1                                                NaN      NaN  676.1
# 2  {'value': 4890, 'currency': 'USD', 'value_usd'...      NaN   17.3
# 3                                                NaN      NaN  276.0
# 4  {'value': 3963, 'currency': 'USD', 'value_usd'...      NaN   12.6
#
#    has_fulltext  cited_by_count  \
# 0         False           29789
# 1          True           11112
# 2          True            7663
# 3         False            6265
# 4         False            6046
#
#                       citation_normalized_percentile cited_by_percentile_year  \
# 0  {'value': 0.999788, 'is_in_top_1_percent': Tru...  {'min': 99, 'max': 100}
# 1  {'value': 0.999941, 'is_in_top_1_percent': Tru...  {'min': 99, 'max': 100}
# 2  {'value': 0.983471, 'is_in_top_1_percent': Fal...  {'min': 99, 'max': 100}
# 3  {'value': 0.999877, 'is_in_top_1_percent': Tru...  {'min': 99, 'max': 100}
# 4  {'value': 0.999966, 'is_in_top_1_percent': Tru...  {'min': 99, 'max': 100}
#
#                                               biblio  is_retracted  \
# 0  {'volume': '49', 'issue': '06', 'first_page': ...         False
# 1  {'volume': '641', 'issue': None, 'first_page':...         False
# 2  {'volume': '81', 'issue': '2', 'first_page': '...         False
# 3  {'volume': '29', 'issue': '2', 'first_page': '...         False
# 4  {'volume': '87', 'issue': '6', 'first_page': '...         False
#
#    is_paratext                                      primary_topic  \
# 0        False  {'id': 'https://openalex.org/T11106', 'display...
# 1        False  {'id': 'https://openalex.org/T10095', 'display...
# 2        False  {'id': 'https://openalex.org/T10302', 'display...
# 3        False  {'id': 'https://openalex.org/T10538', 'display...
# 4        False  {'id': 'https://openalex.org/T10015', 'display...
#
#                                               topics  \
# 0  [{'id': 'https://openalex.org/T11106', 'displa...
# 1  [{'id': 'https://openalex.org/T10095', 'displa...
# 2  [{'id': 'https://openalex.org/T10302', 'displa...
# 3  [{'id': 'https://openalex.org/T10538', 'displa...
# 4  [{'id': 'https://openalex.org/T10015', 'displa...
#
#                                             keywords  \
# 0                                                 []
# 1  [{'id': 'https://openalex.org/keywords/spectra...
# 2  [{'id': 'https://openalex.org/keywords/freshwa...
# 3  [{'id': 'https://openalex.org/keywords/tree', ...
# 4  [{'id': 'https://openalex.org/keywords/conserv...
#
#                                             concepts  \
# 0  [{'id': 'https://openalex.org/C41008148', 'wik...
# 1  [{'id': 'https://openalex.org/C121332964', 'wi...
# 2  [{'id': 'https://openalex.org/C130217890', 'wi...
# 3  [{'id': 'https://openalex.org/C41008148', 'wik...
# 4  [{'id': 'https://openalex.org/C193252679', 'wi...
#
#                                                 mesh  locations_count  \
# 0                                                 []                4
# 1                                                 []               20
# 2  [{'descriptor_ui': 'D044822', 'descriptor_name...                2
# 3                                                 []                1
# 4                                                 []                1
#
#                                            locations  \
# 0  [{'is_oa': False, 'landing_page_url': 'https:/...
# 1  [{'is_oa': True, 'landing_page_url': 'https://...
# 2  [{'is_oa': False, 'landing_page_url': 'https:/...
# 3  [{'is_oa': False, 'landing_page_url': 'https:/...
# 4  [{'is_oa': False, 'landing_page_url': 'https:/...
#
#                                     best_oa_location  \
# 0  {'is_oa': True, 'landing_page_url': 'http://ww...
# 1  {'is_oa': True, 'landing_page_url': 'https://d...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                        sustainable_development_goals grants datasets  \
# 0  [{'score': 0.49, 'display_name': 'Industry, in...     []       []
# 1                                                 []     []       []
# 2  [{'score': 0.7, 'display_name': 'Life on land'...     []       []
# 3                                                 []     []       []
# 4                                                 []     []       []
#
#                                versions  referenced_works_count  \
# 0                                    []                     487
# 1  ['https://openalex.org/W4288079944']                     465
# 2                                    []                     185
# 3                                    []                      18
# 4                                    []                       0
#
#                                     referenced_works  \
# 0  ['https://openalex.org/W101663867', 'https://o...
# 1  ['https://openalex.org/W1481932901', 'https://...
# 2  ['https://openalex.org/W1495628681', 'https://...
# 3  ['https://openalex.org/W1506285740', 'https://...
# 4                                                 []
#
#                                        related_works  \
# 0  ['https://openalex.org/W2899084033', 'https://...
# 1  ['https://openalex.org/W758044194', 'https://o...
# 2  ['https://openalex.org/W98137297', 'https://op...
# 3  ['https://openalex.org/W3034345083', 'https://...
# 4  ['https://openalex.org/W4308441232', 'https://...
#
#                              abstract_inverted_index  \
# 0  {'The': [0], 'increasing': [1], 'volume': [2],...
# 1  {'We': [0, 15, 162], 'present': [1], 'cosmolog...
# 2  {'Freshwater': [0], 'biodiversity': [1, 67, 10...
# 3  {'Mining': [0], 'frequent': [1, 57, 74, 90, 19...
# 4  {'DNA-sequence': [0, 23, 162, 305], 'data': [1...
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W2...
# 1  https://api.openalex.org/works?filter=cites:W4...
# 2  https://api.openalex.org/works?filter=cites:W2...
# 3  https://api.openalex.org/works?filter=cites:W2...
# 4  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0  [{'year': 2025, 'cited_by_count': 300}, {'year...
# 1  [{'year': 2025, 'cited_by_count': 1556}, {'yea...
# 2  [{'year': 2025, 'cited_by_count': 423}, {'year...
# 3  [{'year': 2025, 'cited_by_count': 65}, {'year'...
# 4  [{'year': 2025, 'cited_by_count': 124}, {'year...
#
#                  updated_date created_date is_authors_truncated  \
# 0  2025-10-02T05:46:20.543866   2016-06-24                  NaN
# 1  2025-10-06T10:32:32.377326   2022-07-28                 True
# 2  2025-10-04T09:59:13.297247   2016-06-24                  NaN
# 3  2025-10-02T05:00:17.559516   2016-06-24                  NaN
# 4  2025-10-06T02:23:45.405825   2016-06-24                  NaN
#
#   fulltext_origin
# 0             NaN
# 1             pdf
# 2          ngrams
# 3             NaN
# 4             NaN

# %% [markdown]
# ### 1. Get the subject areas

# %%
# isolate topics, subfields, fields, and domains
sfu_work_topic = sfu_works[['publication_year','primary_topic']]

# extract the topic, subfield, field, and domain
sfu_work_topic_cleaned = pd.DataFrame(sfu_work_topic.dropna().reset_index()[['publication_year','primary_topic']])
sfu_work_topic_cleaned['as_dict'] = sfu_work_topic_cleaned['primary_topic'].apply(ast.literal_eval)
sfu_work_topic_cleaned['open_alex_id'] = sfu_work_topic_cleaned['as_dict'].apply(lambda x: x['id'])
sfu_work_topic_cleaned['topic'] = sfu_work_topic_cleaned['as_dict'].apply(lambda x: x['display_name'])
sfu_work_topic_cleaned['subfield'] = sfu_work_topic_cleaned['as_dict'].apply(lambda x: x['subfield']).apply(lambda y: y['display_name'])
sfu_work_topic_cleaned['field'] = sfu_work_topic_cleaned['as_dict'].apply(lambda x: x['field']).apply(lambda y: y['display_name'])
sfu_work_topic_cleaned['domain'] = sfu_work_topic_cleaned['as_dict'].apply(lambda x: x['domain']).apply(lambda y: y['display_name'])
#sfu_work_topic_cleaned = sfu_work_topic_cleaned.iloc[:,1:]

# print
sfu_work_topic_cleaned
# Out:
#        publication_year                                      primary_topic  \
# 0                  2012  {'id': 'https://openalex.org/T11106', 'display...
# 1                  2020  {'id': 'https://openalex.org/T10095', 'display...
# 2                  2005  {'id': 'https://openalex.org/T10302', 'display...
# 3                  2000  {'id': 'https://openalex.org/T10538', 'display...
# 4                  1994  {'id': 'https://openalex.org/T10015', 'display...
# ...                 ...                                                ...
# 74912              1988  {'id': 'https://openalex.org/T10588', 'display...
# 74913              1984  {'id': 'https://openalex.org/T11859', 'display...
# 74914              1993  {'id': 'https://openalex.org/T10049', 'display...
# 74915              1989  {'id': 'https://openalex.org/T10181', 'display...
# 74916              1989  {'id': 'https://openalex.org/T11010', 'display...
#
#                                                  as_dict  \
# 0      {'id': 'https://openalex.org/T11106', 'display...
# 1      {'id': 'https://openalex.org/T10095', 'display...
# 2      {'id': 'https://openalex.org/T10302', 'display...
# 3      {'id': 'https://openalex.org/T10538', 'display...
# 4      {'id': 'https://openalex.org/T10015', 'display...
# ...                                                  ...
# 74912  {'id': 'https://openalex.org/T10588', 'display...
# 74913  {'id': 'https://openalex.org/T11859', 'display...
# 74914  {'id': 'https://openalex.org/T10049', 'display...
# 74915  {'id': 'https://openalex.org/T10181', 'display...
# 74916  {'id': 'https://openalex.org/T11010', 'display...
#
#                       open_alex_id                                      topic  \
# 0      https://openalex.org/T11106             Data Management and Algorithms
# 1      https://openalex.org/T10095         Cosmology and Gravitation Theories
# 2      https://openalex.org/T10302        Fish Ecology and Management Studies
# 3      https://openalex.org/T10538    Data Mining Algorithms and Applications
# 4      https://openalex.org/T10015          Genomics and Phylogenetic Studies
# ...                            ...                                        ...
# 74912  https://openalex.org/T10588         Mathematical Dynamics and Fractals
# 74913  https://openalex.org/T11859  Educator Training and Historical Pedagogy
# 74914  https://openalex.org/T10049          Magnetic properties of thin films
# 74915  https://openalex.org/T10181     Natural Language Processing Techniques
# 74916  https://openalex.org/T11010            Logic, Reasoning, and Knowledge
#
#                                        subfield  \
# 0                             Signal Processing
# 1                    Astronomy and Astrophysics
# 2             Nature and Landscape Conservation
# 3                           Information Systems
# 4                             Molecular Biology
# ...                                         ...
# 74912                      Mathematical Physics
# 74913           Sociology and Political Science
# 74914  Atomic and Molecular Physics, and Optics
# 74915                   Artificial Intelligence
# 74916                   Artificial Intelligence
#
#                                               field             domain
# 0                                  Computer Science  Physical Sciences
# 1                             Physics and Astronomy  Physical Sciences
# 2                             Environmental Science  Physical Sciences
# 3                                  Computer Science  Physical Sciences
# 4      Biochemistry, Genetics and Molecular Biology      Life Sciences
# ...                                             ...                ...
# 74912                                   Mathematics  Physical Sciences
# 74913                               Social Sciences    Social Sciences
# 74914                         Physics and Astronomy  Physical Sciences
# 74915                              Computer Science  Physical Sciences
# 74916                              Computer Science  Physical Sciences
#
# [74917 rows x 8 columns]

# %% [markdown]
# ### 2. Aggregate and group by subject area

# %%
sfu_topics_agg = pd.DataFrame(sfu_work_topic_cleaned.groupby(['publication_year', 'topic']).count()['open_alex_id'].sort_values(ascending=False)).rename(columns={'open_alex_id': 'count'})
sfu_subfields_agg = pd.DataFrame(sfu_work_topic_cleaned.groupby(['publication_year', 'subfield']).count()['open_alex_id'].sort_values(ascending=False)).rename(columns={'open_alex_id': 'count'})
sfu_fields_agg = pd.DataFrame(sfu_work_topic_cleaned.groupby(['publication_year', 'field']).count()['open_alex_id'].sort_values(ascending=False)).rename(columns={'open_alex_id': 'count'})
sfu_domains_agg = pd.DataFrame(sfu_work_topic_cleaned.groupby(['publication_year', 'domain']).count()['open_alex_id'].sort_values(ascending=False)).rename(columns={'open_alex_id': 'count'})

# %% [markdown]
# ### 3. Save in .csv format

# %%
#sfu_topics_agg.to_csv('../data_pulls/sfu_works_by_topic.csv')
sfu_topics_agg.to_csv('../data_pulls/sfu_works_by_topic.csv')
sfu_subfields_agg.to_csv('../data_pulls/sfu_works_by_subfield.csv')
sfu_fields_agg.to_csv('../data_pulls/sfu_works_by_field.csv')
sfu_domains_agg.to_csv('../data_pulls/sfu_works_by_domain.csv')

# %% [markdown]
# ### BONUS: Calculate institutional FWCI while we're already here

# %%
all_fwcis = sfu_works[['publication_year','fwci']]
all_fwcis
# Out:
#        publication_year   fwci
# 0                  2012 1728.3
# 1                  2020  676.1
# 2                  2005   17.3
# 3                  2000  276.0
# 4                  1994   12.6
# ...                 ...    ...
# 76588              1984    0.0
# 76589              1993    0.0
# 76590              1989    0.0
# 76591              1989    0.0
# 76592              1991    NaN
#
# [76593 rows x 2 columns]

# %%
current_yr = datetime.now().year

sfu_fwci_5yr = np.mean(all_fwcis[all_fwcis['publication_year'] > (current_yr-5)]['fwci'])
sfu_fwci_10yr = np.mean(all_fwcis[all_fwcis['publication_year'] > (current_yr-10)]['fwci'])
total_sfu_fwci = np.mean(all_fwcis['fwci'].dropna())

summary = pd.DataFrame(pd.read_csv('../data_pulls/sfu_summary_stats.csv'))
summary.loc[summary['Time Frame']=='5 years', 'Field-Weighted Citation Impact'] = sfu_fwci_5yr
summary.loc[summary['Time Frame']=='10 years', 'Field-Weighted Citation Impact'] = sfu_fwci_10yr
summary.loc[summary['Time Frame']=='All-time', 'Field-Weighted Citation Impact'] = total_sfu_fwci
#print(summary)

#pd.DataFrame({'FWCI':[total_sfu_fwci]}).to_csv('../data_pulls/sfu_fwci.csv', index=False)
summary.to_csv('../data_pulls/sfu_summary_stats.csv', index=False)
# Out:
#   Time Frame  Publications  Citations  Citations per Publication  h-Index  \
# 0   All-time       78135.0  2593163.0                       33.2    491.0
# 1   10 years           NaN        NaN                        NaN      NaN
# 2    5 years           NaN        NaN                        NaN      NaN
#
#   Field-Weighted Citation Impact        Authors
# 0                            2.8  dont know yet
# 1                            2.7            NaN
# 2                            2.1            NaN

# %% [markdown]
# ### BONUS: Calculate publications per year

# %%
sfu_works_by_year = pd.DataFrame(sfu_works.groupby(['publication_year']).count()['id']).rename(columns={'id': 'Publications'})
sfu_works_by_year.to_csv('../data_pulls/sfu_works_by_year.csv', index=True)
sfu_works_by_year # this exists altready but this one has a longer time scope (but some minor inconsistencies)
# Out:
#                   Publications
# publication_year
# 1964                         1
# 1965                         4
# 1966                        27
# 1967                        57
# 1968                        69
# ...                        ...
# 2021                      3707
# 2022                      3406
# 2023                      3525
# 2024                      2965
# 2025                      1521
#
# [62 rows x 1 columns]
